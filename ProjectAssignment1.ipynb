# %% [markdown]
# <a href="https://colab.research.google.com/github/leksangpelkey/firstproject/blob/main/ProjectAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
missing_values = ["s", "S", "na","--"]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv",na_values = missing_values)

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.head(10)
# Out:
#   School DBN  ... Percent Scoring CR
# 0     01M034  ...                NaN
# 1     01M034  ...                NaN
# 2     01M034  ...                NaN
# 3     01M140  ...                NaN
# 4     01M140  ...                NaN
# 5     01M140  ...                NaN
# 6     01M140  ...                NaN
# 7     01M140  ...                NaN
# 8     01M184  ...               98.0
# 9     01M184  ...               78.4
#
# [10 rows x 15 columns]

# %%
df.tail(10)
# Out:
#        School DBN           School Name  ... Number Scoring CR Percent Scoring CR
# 212321     84X717  Icahn Charter School  ...               6.0              100.0
# 212322     84X717  Icahn Charter School  ...               6.0              100.0
# 212323     84X717  Icahn Charter School  ...               6.0              100.0
# 212324     84X717  Icahn Charter School  ...               NaN                NaN
# 212325     84X717  Icahn Charter School  ...               NaN                NaN
# 212326     84X717  Icahn Charter School  ...               NaN                NaN
# 212327     84X717  Icahn Charter School  ...               NaN                NaN
# 212328     84X717  Icahn Charter School  ...               NaN                NaN
# 212329     84X717  Icahn Charter School  ...               NaN                NaN
# 212330     84X717  Icahn Charter School  ...               NaN                NaN
#
# [10 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df['School Level'].unique()
# Out:
# array(['K-8', 'High school', 'Junior High-Intermediate-Middle',
#        'Secondary School', 'K-12 all grades', 'Elementary'], dtype=object)

# %%
df2 = df[['School Name','School Level','Regents Exam','Year','Total Tested','Number Scoring Below 65']]

# %%
df2
# Out:
#                            School Name  ... Number Scoring Below 65
# 0       P.S. 034 Franklin D. Roosevelt  ...                     NaN
# 1       P.S. 034 Franklin D. Roosevelt  ...                     1.0
# 2       P.S. 034 Franklin D. Roosevelt  ...                     1.0
# 3               P.S. 140 Nathan Straus  ...                     NaN
# 4               P.S. 140 Nathan Straus  ...                     NaN
# ...                                ...  ...                     ...
# 212326            Icahn Charter School  ...                     NaN
# 212327            Icahn Charter School  ...                     NaN
# 212328            Icahn Charter School  ...                     NaN
# 212329            Icahn Charter School  ...                     NaN
# 212330            Icahn Charter School  ...                     NaN
#
# [212331 rows x 6 columns]

# %%
df2.groupby(['School Level']).count()
# Out:
#                                  School Name  ...  Number Scoring Below 65
# School Level                                  ...
# Elementary                                25  ...                        3
# High school                           151160  ...                   100930
# Junior High-Intermediate-Middle        15742  ...                     8425
# K-12 all grades                         8294  ...                     5243
# K-8                                     6858  ...                     3261
# Secondary School                       30252  ...                    19247
#
# [6 rows x 5 columns]

# %%
df3= df2[df2['School Level'].str.contains('K-8')]

# %%
df3['Regents Exam'].unique()
# Out:
# array(['Common Core Algebra', 'Living Environment', 'Common Core English',
#        'Physical Settings/Earth Science', 'U.S. History and Government',
#        'Common Core Geometry', 'Integrated Algebra', 'English',
#        'Global History and Geography', 'Algebra2/Trigonometry',
#        'Common Core Algebra2', 'Geometry', 'Physical Settings/Chemistry'],
#       dtype=object)

# %%
schoolselected= df3[df3['Regents Exam']=='Integrated Algebra']

# %%
schoolselected
# Out:
#                               School Name  ... Number Scoring Below 65
# 2481                  The Anderson School  ...                     0.0
# 14716          P.S./M.S. 114 Belle Harbor  ...                     NaN
# 17721   Hellenic Classical Charter School  ...                     0.0
# 17722   Hellenic Classical Charter School  ...                     NaN
# 17923      Excellence Boys Charter School  ...                     NaN
# 17946     Kings Collegiate Charter School  ...                     4.0
# 18039              Explore Charter School  ...                     0.0
# 19468       Harriet Tubman Charter School  ...                     0.0
# 23961                 The Anderson School  ...                     0.0
# 45797          P.S./M.S. 114 Belle Harbor  ...                     NaN
# 51076   Hellenic Classical Charter School  ...                     0.0
# 51077   Hellenic Classical Charter School  ...                     NaN
# ...

# %%
schoolselected[(schoolselected['School Name']=='Excellence Boys Charter School')|(schoolselected['School Name']=='Kings Collegiate Charter School')].head(15)
# Out:
#        School DBN  ... Number Scoring Below 65
# 17923      84K593  ...                     NaN
# 17946      84K608  ...                     4.0
# 51446      84K593  ...                     NaN
# 51488      84K608  ...                     NaN
# 51489      84K608  ...                     NaN
# 99206      84K593  ...                     NaN
# 99234      84K608  ...                     4.0
# 136922     84K593  ...                     NaN
# 136958     84K608  ...                     NaN
# 136959     84K608  ...                     NaN
# 207565     84K593  ...                     NaN
# 207598     84K608  ...                     4.0
#
# [12 rows x 7 columns]

# %%
schoolselected.groupby(['Year']).count()
# Out:
#       School DBN  School Name  ...  Total Tested  Number Scoring Below 65
# Year                           ...
# 2015          53           53  ...            53                       18
# 2017           5            5  ...             5                        0
#
# [2 rows x 6 columns]

# %%
schoolselected.plot(kind='hist', x='School Name', y='Number Scoring Below 65',title='School Exam');

# %%
schoolselected.groupby(['School Name']).count().plot(kind='hist')

# %%
schoolselected = sns.load_dataset(schoolselected)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-043e7545f4f6> in <module>()
# ----> 1 schoolselected = sns.load_dataset(schoolselected)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     585             "it is not necessary to use this function before plotting."
#     586         )
# --> 587         raise TypeError(err)
#     588
#     589     url = f"https://raw.githubusercontent.com/mwaskom/seaborn-data/master/{name}.csv"
#
# TypeError: This function accepts only strings (the name of an example dataset). You passed a pandas DataFrame. If you have your own dataset, it is not necessary to use this function before plotting.
