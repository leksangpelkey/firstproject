# %% [markdown]
# <a href="https://colab.research.google.com/github/leksangpelkey/firstproject/blob/main/ProjectAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
missing_values = ["s", "S", "na","--"]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv",na_values = missing_values)

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.head(10)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#           Regents Exam  Year  Total Tested  Mean Score  \
# 0  Common Core Algebra  2017             4         NaN
# 1   Living Environment  2015            16        77.9
# 2   Living Environment  2016             9        74.0
# 3  Common Core Algebra  2016             3         NaN
# 4  Common Core Algebra  2017             2         NaN
# 5   Living Environment  2015             9        67.4
# 6   Living Environment  2016            15        72.6
# 7   Living Environment  2017             9        64.4
# 8  Common Core Algebra  2015            49        78.4
# 9  Common Core Algebra  2016            51        79.0
#
#    Number Scoring Below 65  Percent Scoring Below 65  \
# 0                      NaN                       NaN
# 1                      1.0                       6.3
# 2                      1.0                      11.1
# 3                      NaN                       NaN
# 4                      NaN                       NaN
# 5                      3.0                      33.3
# 6                      2.0                      13.3
# 7                      5.0                      55.6
# 8                      1.0                       2.0
# 9                      9.0                      17.6
#
#    Number Scoring 65 or Above  Percent Scoring 65 or Above  \
# 0                         NaN                          NaN
# 1                        15.0                         93.8
# 2                         8.0                         88.9
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# 5                         6.0                         66.7
# 6                        13.0                         86.7
# 7                         4.0                         44.4
# 8                        48.0                         98.0
# 9                        42.0                         82.4
#
#    Number Scoring 80 or Above  Percent Scoring 80 or Above  Number Scoring CR  \
# 0                         NaN                          NaN                NaN
# 1                         7.0                         43.8                NaN
# 2                         2.0                         22.2                NaN
# 3                         NaN                          NaN                NaN
# 4                         NaN                          NaN                NaN
# 5                         0.0                          0.0                NaN
# 6                         5.0                         33.3                NaN
# 7                         1.0                         11.1                NaN
# 8                        23.0                         46.9               48.0
# 9                        33.0                         64.7               40.0
#
#    Percent Scoring CR
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                98.0
# 9                78.4

# %%
df.tail(10)
# Out:
#        School DBN           School Name School Level  \
# 212321     84X717  Icahn Charter School          K-8
# 212322     84X717  Icahn Charter School          K-8
# 212323     84X717  Icahn Charter School          K-8
# 212324     84X717  Icahn Charter School          K-8
# 212325     84X717  Icahn Charter School          K-8
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# 212321          Common Core Algebra  2016             6        87.2
# 212322          Common Core Algebra  2017             6        87.0
# 212323          Common Core Algebra  2017             6        88.3
# 212324           Living Environment  2015             8        76.5
# 212325           Living Environment  2015             6        79.8
# 212326           Living Environment  2016             8         NaN
# 212327           Living Environment  2016             5         NaN
# 212328           Living Environment  2017             6         NaN
# 212329           Living Environment  2017             4         NaN
# 212330  U.S. History and Government  2015             1         NaN
#
#         Number Scoring Below 65  Percent Scoring Below 65  \
# 212321                      0.0                       0.0
# 212322                      0.0                       0.0
# 212323                      0.0                       0.0
# 212324                      1.0                      12.5
# 212325                      0.0                       0.0
# 212326                      NaN                       NaN
# 212327                      NaN                       NaN
# 212328                      NaN                       NaN
# 212329                      NaN                       NaN
# 212330                      NaN                       NaN
#
#         Number Scoring 65 or Above  Percent Scoring 65 or Above  \
# 212321                         6.0                        100.0
# 212322                         6.0                        100.0
# 212323                         6.0                        100.0
# 212324                         7.0                         87.5
# 212325                         6.0                        100.0
# 212326                         NaN                          NaN
# 212327                         NaN                          NaN
# 212328                         NaN                          NaN
# 212329                         NaN                          NaN
# 212330                         NaN                          NaN
#
#         Number Scoring 80 or Above  Percent Scoring 80 or Above  \
# 212321                         6.0                        100.0
# 212322                         6.0                        100.0
# 212323                         5.0                         83.3
# 212324                         2.0                         25.0
# 212325                         2.0                         33.3
# 212326                         NaN                          NaN
# 212327                         NaN                          NaN
# 212328                         NaN                          NaN
# 212329                         NaN                          NaN
# 212330                         NaN                          NaN
#
#         Number Scoring CR  Percent Scoring CR
# 212321                6.0               100.0
# 212322                6.0               100.0
# 212323                6.0               100.0
# 212324                NaN                 NaN
# 212325                NaN                 NaN
# 212326                NaN                 NaN
# 212327                NaN                 NaN
# 212328                NaN                 NaN
# 212329                NaN                 NaN
# 212330                NaN                 NaN

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df['School Level'].unique()
# Out:
# array(['K-8', 'High school', 'Junior High-Intermediate-Middle',
#        'Secondary School', 'K-12 all grades', 'Elementary'], dtype=object)

# %%
df2 = df[['School Name','School Level','Regents Exam','Year','Total Tested','Number Scoring Below 65']]

# %%
df2.shape
# Out:
# (212331, 6)

# %%
df2.drop_duplicates(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# droping the duplicate and checking if the effect has been taken by going through the shape of dataframe, i see that 25173 rows are removed after dropna function

# %%
df2.shape
# Out:
# (187158, 6)

# %%
df2.groupby(['School Level']).count()
# Out:
#                                  School Name  Regents Exam    Year  \
# School Level
# Elementary                                10            10      10
# High school                           135474        135474  135474
# Junior High-Intermediate-Middle        12550         12550   12550
# K-12 all grades                         7429          7429    7429
# K-8                                     4996          4996    4996
# Secondary School                       26699         26690   26699
#
#                                  Total Tested  Number Scoring Below 65
# School Level
# Elementary                                 10                        1
# High school                            135474                    98504
# Junior High-Intermediate-Middle         12550                     7673
# K-12 all grades                          7429                     5097
# K-8                                      4996                     2645
# Secondary School                        26699                    18436

# %%
df3= df2[df2['School Level'].str.contains('K-8')]

# %%
df3['Regents Exam'].unique()
# Out:
# array(['Common Core Algebra', 'Living Environment', 'Common Core English',
#        'Physical Settings/Earth Science', 'U.S. History and Government',
#        'Common Core Geometry', 'Integrated Algebra', 'English',
#        'Global History and Geography', 'Algebra2/Trigonometry',
#        'Common Core Algebra2', 'Geometry', 'Physical Settings/Chemistry'],
#       dtype=object)

# %%
schoolselected= df3[df3['Regents Exam']=='Integrated Algebra']

# %%
schoolselected
# Out:
#                               School Name School Level        Regents Exam  \
# 2481                  The Anderson School          K-8  Integrated Algebra
# 14716          P.S./M.S. 114 Belle Harbor          K-8  Integrated Algebra
# 17721   Hellenic Classical Charter School          K-8  Integrated Algebra
# 17722   Hellenic Classical Charter School          K-8  Integrated Algebra
# 17923      Excellence Boys Charter School          K-8  Integrated Algebra
# 17946     Kings Collegiate Charter School          K-8  Integrated Algebra
# 18039              Explore Charter School          K-8  Integrated Algebra
# 19468       Harriet Tubman Charter School          K-8  Integrated Algebra
# 51488     Kings Collegiate Charter School          K-8  Integrated Algebra
# 51489     Kings Collegiate Charter School          K-8  Integrated Algebra
# 54222       Harriet Tubman Charter School          K-8  Integrated Algebra
# 54223       Harriet Tubman Charter School          K-8  Integrated Algebra
# 60495                 The Anderson School          K-8  Integrated Algebra
# 60496                 The Anderson School          K-8  Integrated Algebra
# 99422              Explore Charter School          K-8  Integrated Algebra
# 99423              Explore Charter School          K-8  Integrated Algebra
# 102867      Harriet Tubman Charter School          K-8  Integrated Algebra
# 102868      Harriet Tubman Charter School          K-8  Integrated Algebra
# 107612                The Anderson School          K-8  Integrated Algebra
# 107613                The Anderson School          K-8  Integrated Algebra
# 134350                The Anderson School          K-8  Integrated Algebra
# 136552  Hellenic Classical Charter School          K-8  Integrated Algebra
# 136553  Hellenic Classical Charter School          K-8  Integrated Algebra
# 136958    Kings Collegiate Charter School          K-8  Integrated Algebra
# 136959    Kings Collegiate Charter School          K-8  Integrated Algebra
# 137130             Explore Charter School          K-8  Integrated Algebra
# 137131             Explore Charter School          K-8  Integrated Algebra
# 139867      Harriet Tubman Charter School          K-8  Integrated Algebra
# 139868      Harriet Tubman Charter School          K-8  Integrated Algebra
# 149673                The Anderson School          K-8  Integrated Algebra
# 149906                The Anderson School          K-8  Integrated Algebra
# 149907                The Anderson School          K-8  Integrated Algebra
# 149908                The Anderson School          K-8  Integrated Algebra
# 207021  Hellenic Classical Charter School          K-8  Integrated Algebra
# 207022  Hellenic Classical Charter School          K-8  Integrated Algebra
# 207865             Explore Charter School          K-8  Integrated Algebra
# 207866             Explore Charter School          K-8  Integrated Algebra
# 212314      Harriet Tubman Charter School          K-8  Integrated Algebra
# 212315      Harriet Tubman Charter School          K-8  Integrated Algebra
#
#         Year  Total Tested  Number Scoring Below 65
# 2481    2015            61                      0.0
# 14716   2015             2                      NaN
# 17721   2015            15                      0.0
# 17722   2017             1                      NaN
# 17923   2015             4                      NaN
# 17946   2015             8                      4.0
# 18039   2015            10                      0.0
# 19468   2015            16                      0.0
# 51488   2015             3                      NaN
# 51489   2015             5                      NaN
# 54222   2015            14                      NaN
# 54223   2015             2                      NaN
# 60495   2015            59                      NaN
# 60496   2015             2                      NaN
# 99422   2015             8                      NaN
# 99423   2015             2                      NaN
# 102867  2015            12                      NaN
# 102868  2015             4                      NaN
# 107612  2015            30                      0.0
# 107613  2015            31                      0.0
# 134350  2015             3                      NaN
# 136552  2015            11                      NaN
# 136553  2015             4                      NaN
# 136958  2015             2                      NaN
# 136959  2015             6                      NaN
# 137130  2015             6                      NaN
# 137131  2015             4                      NaN
# 139867  2015            10                      0.0
# 139868  2015             6                      0.0
# 149673  2015             4                      NaN
# 149906  2015            20                      0.0
# 149907  2015             1                      NaN
# 149908  2015            33                      0.0
# 207021  2015             9                      0.0
# 207022  2015             3                      NaN
# 207865  2015             9                      NaN
# 207866  2015             1                      NaN
# 212314  2015            13                      NaN
# 212315  2015             3                      NaN

# %%
ax = sns.barplot(x='School Name', y ='Total Tested', data =schoolselected)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# Out:
# [Text(0, 0, 'The Anderson School'),
#  Text(0, 0, 'P.S./M.S. 114 Belle Harbor'),
#  Text(0, 0, 'Hellenic Classical Charter School'),
#  Text(0, 0, 'Excellence Boys Charter School'),
#  Text(0, 0, 'Kings Collegiate Charter School'),
#  Text(0, 0, 'Explore Charter School'),
#  Text(0, 0, 'Harriet Tubman Charter School')]

# %%
twoschoolselected = schoolselected[(schoolselected['School Name']=='The Anderson School')|(schoolselected['School Name']=='Kings Collegiate Charter School')].head(15)

# %%
twoschoolselected
# Out:
#                             School Name School Level        Regents Exam  \
# 2481                The Anderson School          K-8  Integrated Algebra
# 17946   Kings Collegiate Charter School          K-8  Integrated Algebra
# 51488   Kings Collegiate Charter School          K-8  Integrated Algebra
# 51489   Kings Collegiate Charter School          K-8  Integrated Algebra
# 60495               The Anderson School          K-8  Integrated Algebra
# 60496               The Anderson School          K-8  Integrated Algebra
# 107612              The Anderson School          K-8  Integrated Algebra
# 107613              The Anderson School          K-8  Integrated Algebra
# 134350              The Anderson School          K-8  Integrated Algebra
# 136958  Kings Collegiate Charter School          K-8  Integrated Algebra
# 136959  Kings Collegiate Charter School          K-8  Integrated Algebra
# 149673              The Anderson School          K-8  Integrated Algebra
# 149906              The Anderson School          K-8  Integrated Algebra
# 149907              The Anderson School          K-8  Integrated Algebra
# 149908              The Anderson School          K-8  Integrated Algebra
#
#         Year  Total Tested  Number Scoring Below 65
# 2481    2015            61                      0.0
# 17946   2015             8                      4.0
# 51488   2015             3                      NaN
# 51489   2015             5                      NaN
# 60495   2015            59                      NaN
# 60496   2015             2                      NaN
# 107612  2015            30                      0.0
# 107613  2015            31                      0.0
# 134350  2015             3                      NaN
# 136958  2015             2                      NaN
# 136959  2015             6                      NaN
# 149673  2015             4                      NaN
# 149906  2015            20                      0.0
# 149907  2015             1                      NaN
# 149908  2015            33                      0.0

# %%
##two school selected for comparison

# %%
sns.barplot(x='School Name', y ='Total Tested', data =twoschoolselected).set(title="Highest Total Students Tested")
# Out:
# [Text(0.5, 1.0, 'Highest Total Students Tested')]
